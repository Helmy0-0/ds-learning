# %%
# Task 1: Implement Math Formula for Linear Regression
import numpy as np

def predict(X, theta):
    return np.dot(X, theta)

# Generate synthetic data for testing
np.random.seed(42)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Add bias term to X
X_b = np.c_[np.ones((100, 1)), X]

# Initialize parameters
theta = np.random.randn(2, 1)
learning_rate = 0.1
iterations = 1000

# Task 2: Use Gradient Descent to Optimize Parameters
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    for _ in range(iterations):
        gradients = (1/m) * np.dot(X.T, (predict(X, theta) - y))
        theta -= learning_rate * gradients
    return theta

# Task 3: Calculate Evaluation Metrics
def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

def r_squared(y_true, y_pred):
    ss_residual = np.sum((y_true - y_pred) ** 2)
    ss_total = np.sum((y_true - np.mean(y_true)) ** 2)
    return 1 - (ss_residual / ss_total)

# Perform gradient descent to find optimal parameters
theta_optimized = gradient_descent(X_b, y, theta, learning_rate, iterations)

# Predictions and Evaluation
y_pred = predict(X_b, theta_optimized)
mse = mean_squared_error(y, y_pred)
r2 = r_squared(y, y_pred)

print("Optimized Parameters (theta):", theta_optimized)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Optimized Parameters (theta): [[4.21509609]
#  [2.77011344]]
# Mean Squared Error: 0.8065845639670546
# R-squared: 0.769273541361422
