# %%
from scipy.stats import chi2_contingency, f_oneway, ttest_1samp, ttest_ind, ttest_rel

# %% [markdown]
# ### Sample

# %%
# Contingency table
data = [[50, 30], [20, 40]]

# Perform chi-square test
chi2, p, dof, expected = chi2_contingency(data)
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Expected frequencies: \n{expected}")

# Data for three groups
group1 = [12, 14, 15, 16, 17]
group2 = [11, 13, 14, 15, 16]
group3 = [10, 12, 13, 14, 15]

# Perform ANOVA test
f_stat, p_value = f_oneway(group1, group2, group3)
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")
# Out:
# Chi-square statistic: 10.529166666666667
# P-value: 0.0011750518530845063
# Expected frequencies:
# [[40. 40.]
#  [30. 30.]]
# F-statistic: 1.3513513513513515
# P-value: 0.29559999508292545

# %% [markdown]
# ### Exercise 1: Conduct T-test

# %%
# Conduct T-test
# Perform one-sample, two-sample, paired t-test

# One-sample t-test
data = [12, 14, 15, 16, 17]
population_mean = 15
t_stat, p_value = ttest_1samp(data, population_mean)
print(f"One-sample t-test: t-statistic = {t_stat}, p-value = {p_value}")

# Two-sample t-test
group1 = [12, 14, 15, 16, 17]
group2 = [11, 13, 14, 15, 16]
t_stat, p_value = ttest_ind(group1, group2)
print(f"Two-sample t-test: t-statistic = {t_stat}, p-value = {p_value}")

# Paired t-test
pre_test = [12, 14, 15, 16, 17]
post_test = [13, 14, 16, 17, 18]
t_stat, p_value = ttest_rel(pre_test, post_test)
print(f"Paired t-test: t-statistic = {t_stat}, p-value = {p_value}")
# Out:
# One-sample t-test: t-statistic = -0.23249527748763774, p-value = 0.8275647196020324
# Two-sample t-test: t-statistic = 0.8219949365267863, p-value = 0.43489229767474047
# Paired t-test: t-statistic = -3.9999999999999996, p-value = 0.016130089900092532

# %% [markdown]
# ### Exercise 2: Perform a Chi-Square Test

# %%
# Contingency table for chi-square test
data = [[50, 30, 20], [30, 40, 30]]

# Perform chi-square test
chi2, p, dof, expected = chi2_contingency(data)
print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Expected frequencies: \n{expected}")
# Out:
# Chi-square statistic: 8.428571428571429
# P-value: 0.014782877194839422
# Expected frequencies:
# [[40. 35. 25.]
#  [40. 35. 25.]]

# %% [markdown]
# ### Exercise 3: Conduct ANOVA

# %%
# Data for three groups
group1 = [10, 12, 14, 16, 18]
group2 = [9, 11, 13, 15, 17]
group3 = [8, 10, 12, 14, 16]

# Perform ANOVA test
f_stat, p_value = f_oneway(group1, group2, group3)
print(f"F-statistic: {f_stat}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 0.5
# P-value: 0.6186248513251718
